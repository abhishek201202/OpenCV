# %%
import cv2
import matplotlib.pyplot as plt

# %%
imgpath = "C:/Users/User/OpenCv/misc/5.1.11.tiff"
img = cv2.imread(imgpath)
L1 = cv2.Canny(img, 50, 300, L2gradient = False)
L2 = cv2.Canny(img, 100, 150, L2gradient = True)
output = [img, L1, L2]
titles = ["Original", "L1", "L2"]

for i in range(len(output)):
    plt.subplot(1, 3, i + 1)
    plt.imshow(output[i], cmap = "gray")
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
imgpath = "C:/Users/User/OpenCv/misc/7.1.02.tiff"
img = cv2.imread(imgpath)
L1 = cv2.Canny(img, 50, 300, L2gradient = False)
L2 = cv2.Canny(img, 100, 150, L2gradient = True)
output = [img, L1, L2]
titles = ["Original", "L1", "L2"]

for i in range(len(output)):
    plt.subplot(1, 3, i + 1)
    plt.imshow(output[i], cmap = "gray")
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
imgpath = "C:/Users/User/OpenCv/misc/5.1.12.tiff"
img = cv2.imread(imgpath)
L1 = cv2.Canny(img, 50, 300, L2gradient = False)
L2 = cv2.Canny(img, 100, 150, L2gradient = True)
output = [img, L1, L2]
titles = ["Original", "L1", "L2"]

for i in range(len(output)):
    plt.subplot(1, 3, i + 1)
    plt.imshow(output[i], cmap = "gray")
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()
